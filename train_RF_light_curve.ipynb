# %% [markdown]
# # **Random Forest model training**

# %% [markdown]
# ## **Import libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import os

# %% [markdown]
# ## **Split to train and test data**

# %% [markdown]
# ## **Read & Process data**

# %%
# Load the second CSV file with the first column as the index
combined_df = pd.read_csv('tsfresh_features.csv', index_col=0)
# combined_df.index = combined_df['Unnamed: 0']
combined_df = combined_df.sort_index()
comparison_file_path = 'q1_q17_dr25_koi.csv'
comparison_df = pd.read_csv(comparison_file_path, index_col=1)

# Restrict to the first 900 rows of the second CSV
comparison_df = comparison_df.iloc[:2000]

# Find the missing indices
missing_indices = comparison_df.index.difference(combined_df.index)

# Display the missing indices
if missing_indices.empty:
    print("No missing indices found.")
else:
  print("Missing indices:")
  print(missing_indices)

# print(combined_df.index)
# Out:
# Missing indices:
# Index(['K00787.01', 'K00787.02', 'K00787.03', 'K00930.01', 'K00961.01',
#        'K00961.02', 'K00961.03', 'K00966.01', 'K01000.01', 'K01013.01',
#        ...
#        'K01515.02', 'K01516.01', 'K01517.01', 'K01518.01', 'K01519.01',
#        'K01519.02', 'K01520.01', 'K01521.01', 'K01522.01', 'K01522.02'],
#       dtype='object', length=134)

# %%
# Calculating koi_disposition column
comparison_file_path = 'q1_q17_dr25_koi.csv'
comparison_df = pd.read_csv(comparison_file_path, index_col=1)
comparison_df2 = comparison_df[1600:2000]
value_counts = comparison_df2['koi_disposition'].value_counts()

# Show how many CONFIRMED and Others
confirmed_count = value_counts.get('CONFIRMED', 0)
other_count = value_counts.sum() - confirmed_count

print(f"CONFIRMED : {confirmed_count}")
print(f"Others    : {other_count}")
# print(comparison_df2[0:1])
# Out:
# CONFIRMED : 218
# Others    : 182

# %%
# Check for duplicate indices in combined_df
combined_df = combined_df.loc[~combined_df.index.duplicated(keep='first')]
duplicate_indices_combined = combined_df.index[combined_df.index.duplicated(keep=False)]

if not duplicate_indices_combined.empty:
    print("Duplicate indices found in combined_df:")
    print(duplicate_indices_combined)
else:
    print("No duplicate indices found in combined_df.")
# Out:
# No duplicate indices found in combined_df.

# %%
# Fill all the nan value with 0
combined_df = combined_df.fillna(0)

# Find rows and columns with NaN values
nan_rows_cols = combined_df[combined_df.isna().any(axis=1)]

if not nan_rows_cols.empty:
    print("Rows and columns with NaN values:")
    for index, row in nan_rows_cols.iterrows():
        nan_cols = row.index[row.isna()]
        print(f"Row index: {index}, Columns with NaN: {list(nan_cols)}")
else:
    print("No NaN values found in the DataFrame.")
# Out:
# No NaN values found in the DataFrame.

# %%
# Identify columns with all the same values or entirely NaN
same_value_columns = []
same_value_data = {}  # Dictionary to store the value each same column holds
nan_columns = []

# Check for columns with a single unique value
for col in combined_df.columns:
    if combined_df[col].nunique(dropna=True) == 1:  # Only one unique value (ignoring NaNs)
        # Store the unique value for columns with the same value
        unique_value = combined_df[col].dropna().iloc[0]  # Get the non-NaN value
        same_value_columns.append(col)
        same_value_data[col] = unique_value

# Check for columns with all NaN values
nan_columns = combined_df.columns[combined_df.isna().all()].tolist()

# Print out the results
print("Columns with the same value:")
for col in same_value_columns:
    print(f"{col}: {same_value_data[col]}")

print("\nColumns with all NaN values:")
print(nan_columns)

# Combine columns to drop
columns_to_drop = list(set(same_value_columns + nan_columns))

# Remove duplicates in case of overlap
columns_to_drop = list(set(columns_to_drop))

# List the columns to drop
print("Columns to drop:", columns_to_drop)
# Out:
# Columns with the same value:
# light_curve__variance_larger_than_standard_deviation: 0.0
# light_curve__has_duplicate_max: 0.0
# light_curve__has_duplicate_min: 0.0
# light_curve__has_duplicate: 0.0
# light_curve__percentage_of_reoccurring_values_to_all_values: 0.0
# light_curve__percentage_of_reoccurring_datapoints_to_all_datapoints: 0.0
# light_curve__sum_of_reoccurring_values: 0.0
# light_curve__sum_of_reoccurring_data_points: 0.0
# light_curve__ratio_value_number_to_time_series_length: 1.0
# light_curve__symmetry_looking__r_0.0: 0.0
# light_curve__symmetry_looking__r_0.2: 1.0
# light_curve__symmetry_looking__r_0.25: 1.0
# light_curve__symmetry_looking__r_0.30000000000000004: 1.0
# light_curve__symmetry_looking__r_0.35000000000000003: 1.0
# light_curve__symmetry_looking__r_0.4: 1.0
# light_curve__symmetry_looking__r_0.45: 1.0
# light_curve__symmetry_looking__r_0.5: 1.0
# light_curve__symmetry_looking__r_0.55: 1.0
# light_curve__symmetry_looking__r_0.6000000000000001: 1.0
# light_curve__symmetry_looking__r_0.65: 1.0
# light_curve__symmetry_looking__r_0.7000000000000001: 1.0
# light_curve__symmetry_looking__r_0.75: 1.0
# light_curve__symmetry_looking__r_0.8: 1.0
# light_curve__symmetry_looking__r_0.8500000000000001: 1.0
# light_curve__symmetry_looking__r_0.9: 1.0
# light_curve__symmetry_looking__r_0.9500000000000001: 1.0
# light_curve__large_standard_deviation__r_0.35000000000000003: 0.0
# light_curve__large_standard_deviation__r_0.4: 0.0
# light_curve__large_standard_deviation__r_0.45: 0.0
# light_curve__large_standard_deviation__r_0.5: 0.0
# light_curve__large_standard_deviation__r_0.55: 0.0
# light_curve__large_standard_deviation__r_0.6000000000000001: 0.0
# light_curve__large_standard_deviation__r_0.65: 0.0
# light_curve__large_standard_deviation__r_0.7000000000000001: 0.0
# light_curve__large_standard_deviation__r_0.75: 0.0
# light_curve__large_standard_deviation__r_0.8: 0.0
# light_curve__large_standard_deviation__r_0.8500000000000001: 0.0
# light_curve__large_standard_deviation__r_0.9: 0.0
# light_curve__large_standard_deviation__r_0.9500000000000001: 0.0
# light_curve__partial_autocorrelation__lag_0: 1.0
# light_curve__fft_coefficient__attr_"imag"__coeff_0: 0.0
# light_curve__value_count__value_0: 0.0
# light_curve__value_count__value_1: 0.0
# light_curve__value_count__value_-1: 0.0
# light_curve__query_similarity_count__query_None__threshold_0.0: 0.0
#
# Columns with all NaN values:
# []
# Columns to drop: ['light_curve__symmetry_looking__r_0.25', 'light_curve__symmetry_looking__r_0.2', 'light_curve__symmetry_looking__r_0.0', 'light_curve__percentage_of_reoccurring_datapoints_to_all_datapoints', 'light_curve__has_duplicate_max', 'light_curve__value_count__value_0', 'light_curve__symmetry_looking__r_0.5', 'light_curve__symmetry_looking__r_0.45', 'light_curve__symmetry_looking__r_0.4', 'light_curve__large_standard_deviation__r_0.8', 'light_curve__large_standard_deviation__r_0.75', 'light_curve__value_count__value_1', 'light_curve__value_count__value_-1', 'light_curve__large_standard_deviation__r_0.6000000000000001', 'light_curve__large_standard_deviation__r_0.7000000000000001', 'light_curve__symmetry_looking__r_0.9', 'light_curve__symmetry_looking__r_0.9500000000000001', 'light_curve__has_duplicate', 'light_curve__large_standard_deviation__r_0.45', 'light_curve__has_duplicate_min', 'light_curve__symmetry_looking__r_0.7000000000000001', 'light_curve__variance_larger_than_standard_deviation', 'light_curve__ratio_value_number_to_time_series_length', 'light_curve__symmetry_looking__r_0.65', 'light_curve__large_standard_deviation__r_0.9', 'light_curve__fft_coefficient__attr_"imag"__coeff_0', 'light_curve__symmetry_looking__r_0.30000000000000004', 'light_curve__query_similarity_count__query_None__threshold_0.0', 'light_curve__large_standard_deviation__r_0.5', 'light_curve__percentage_of_reoccurring_values_to_all_values', 'light_curve__sum_of_reoccurring_data_points', 'light_curve__symmetry_looking__r_0.6000000000000001', 'light_curve__symmetry_looking__r_0.35000000000000003', 'light_curve__symmetry_looking__r_0.8', 'light_curve__large_standard_deviation__r_0.55', 'light_curve__large_standard_deviation__r_0.8500000000000001', 'light_curve__large_standard_deviation__r_0.9500000000000001', 'light_curve__sum_of_reoccurring_values', 'light_curve__symmetry_looking__r_0.8500000000000001', 'light_curve__symmetry_looking__r_0.55', 'light_curve__large_standard_deviation__r_0.35000000000000003', 'light_curve__partial_autocorrelation__lag_0', 'light_curve__large_standard_deviation__r_0.4', 'light_curve__large_standard_deviation__r_0.65', 'light_curve__symmetry_looking__r_0.75']

# %%
koi_features = combined_df.drop(columns=columns_to_drop)

# %%
inf_columns = koi_features.columns[(koi_features == float('inf')).any() | (koi_features == float('-inf')).any()]

# Loop through each column with inf values and display the indices
for col in inf_columns:
    # Get the indices of rows where the column has inf values
    inf_indices = koi_features[koi_features[col].isin([float('inf'), float('-inf')])].index
    print(f"Indices with inf values in column '{col}':")
    print(inf_indices)

# %%
# Drop rows where any column has inf values
koi_features = koi_features[~koi_features.isin([float('inf'), float('-inf')]).any(axis=1)]
print("Shape of the cleaned data:", koi_features.shape)
# Out:
# Shape of the cleaned data: (1866, 739)

# %%
# Find rows and columns with NaN values
nan_rows_cols = koi_features[koi_features.isna().any(axis=1)]

if not nan_rows_cols.empty:
    print("Rows and columns with NaN values:")
    for index, row in nan_rows_cols.iterrows():
        nan_cols = row.index[row.isna()]
        print(f"Row index: {index}, Columns with NaN: {list(nan_cols)}")
else:
    print("No NaN values found in the DataFrame.")
# Out:
# No NaN values found in the DataFrame.

# %%
pca_data = koi_features
# Extract the 'label' column as the target for training
koi_labels = koi_features.pop('label')
# Show the distribution of Label
koi_labels.value_counts()
# Out:
# label
# 1    1216
# 0     650
# Name: count, dtype: int64

# %% [markdown]
# ## **Split train test**

# %%
train_features = koi_features.loc[:'K01126.01']
train_labels = koi_labels.loc[:'K01126.01']

test_features = koi_features.loc['K01126.02':]
test_labels = koi_labels.loc['K01126.02':]

# %%
# Show the distribution of Label
test_labels.value_counts()
# Out:
# label
# 1    187
# 0    182
# Name: count, dtype: int64

# %%
x_train, y_train, = train_features[:1300],train_labels[:1300]
x_val , y_val = train_features[1301:],train_labels[1301:]
x_test, y_test = test_features,test_labels
print(len(x_train),len(x_val),len(x_test))
# Out:
# 1300 196 369

# %% [markdown]
# # **Finding the best parameters**

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Try to get your best parameters by changing or adding some "grid" below
param_grid = {
    'n_estimators': [50,100],
    'max_depth': [2, 4, 6, 8],
    'min_samples_split': [2, 5,7,9],
    'min_samples_leaf': [1, 2,3,4]
}

grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Check best parameters
print(f"Best parameters: {grid_search.best_params_}")
# Out:
# Best parameters: {'max_depth': 8, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 50}

# %%
max_depth = grid_search.best_params_['max_depth']
min_samples_leaf = grid_search.best_params_['min_samples_leaf']
min_samples_split = grid_search.best_params_['min_samples_split']
print(f'{max_depth=}\n{min_samples_leaf=}\n{min_samples_split=}')
# Out:
# max_depth=8
# min_samples_leaf=4
# min_samples_split=9

# %%
train_accuracy = []
test_accuracy = []
train_f1 = []
test_f1 = []

# Change the range to test more epochs
for n_estimators in range(1, 100):
    clf = RandomForestClassifier(max_depth=max_depth,min_samples_leaf=min_samples_leaf,min_samples_split=min_samples_split,n_estimators=n_estimators,random_state=39)
    clf.fit(x_train, y_train)
    
    # Evaluating
    train_accuracy.append(metrics.accuracy_score(y_train, clf.predict(x_train)))
    test_accuracy.append(metrics.accuracy_score(y_test, clf.predict(x_test)))
    train_f1.append(metrics.f1_score(y_test, clf.predict(x_test)))
    test_f1.append(metrics.f1_score(y_test, clf.predict(x_test)))

# %%
# Ploting accuracy graph
plt.figure(figsize=(10, 6))
plt.plot(range(1, 100), train_accuracy, label='Train Accuracy')
plt.plot(range(1, 100), test_accuracy, label='Test Accuracy')
plt.plot(range(1, 100), train_f1, label='Train F1')
plt.plot(range(1, 100), test_f1, label='Test F1')
plt.xlabel('Number of Trees')
plt.ylabel('Accuracy & F1')
plt.title('Accuracy & F1 vs. Number of Trees')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Getting best epochs
m = max(test_f1)
best_epoch = 0
print(m)
for i in range(len(test_f1)):
    if test_f1[i]==m:
        best_epoch = i+1
print(f'{best_epoch=}')
# Out:
# 0.8045454545454546
# best_epoch=14

# %%
clf = RandomForestClassifier(max_depth=max_depth,min_samples_leaf=min_samples_leaf,min_samples_split=min_samples_split,n_estimators=best_epoch,random_state=39)
clf.fit(x_train,y_train)

y_pred_val = clf.predict(x_val)

precision = metrics.precision_score(y_val,y_pred_val)#,average='micro')
recall = metrics.recall_score(y_val,y_pred_val)#,average='micro')
accuracy = metrics.accuracy_score(y_val,y_pred_val)
f1 = metrics.f1_score(y_val,y_pred_val)#,average='micro')
print(f'{accuracy=:.2f}\n{precision=:.2f}\n{recall=:.2f}\n{f1=:.2f}')

cm = metrics.confusion_matrix(y_val, y_pred_val)

# Plotting confusion matrics
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# accuracy=0.70
# precision=0.63
# recall=0.96
# f1=0.76

# %%
from sklearn.model_selection import cross_val_score

# Calculate cross validation score
cv_scores = cross_val_score(clf, x_train, y_train, cv=10)

# Plot cross validation scores
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), cv_scores, marker='o', linestyle='-', color='g', label='clf')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Cross-validation Accuracy per Fold')
plt.legend()
plt.grid(True)
plt.show()

# %%
feature_importance = clf.feature_importances_

# Save features' name into feature_names
feature_names = x_train.columns[:].tolist()

# Combine feature names with their importance scores
feature_importance_dict = {feature_names[i]: feature_importance[i] for i in range(len(feature_names))}

# Sort the features by importance (descending order)
sorted_features = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# Display the sorted features
print("Sorted Feature Importance:")
for feature, score in sorted_features[:50]:  # Top 50 features
    print(f"{feature}: {score}")
# Out:
# Sorted Feature Importance:
# light_curve__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0: 0.03835257192295247
# light_curve__permutation_entropy__dimension_3__tau_1: 0.030728869342619525
# light_curve__fft_coefficient__attr_"abs"__coeff_4: 0.026099798334284826
# light_curve__variance: 0.020094844669095342
# light_curve__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min": 0.019216011631787388
# light_curve__standard_deviation: 0.017664111385336242
# light_curve__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"min": 0.01725172835787881
# light_curve__quantile__q_0.1: 0.015044851109497754
# light_curve__ar_coefficient__coeff_1__k_10: 0.014645487529330219
# light_curve__fft_coefficient__attr_"real"__coeff_1: 0.014357097776124705
# light_curve__mean: 0.012875072187483839
# light_curve__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean": 0.012710427381561848
# light_curve__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min": 0.012589767069416684
# light_curve__linear_trend__attr_"rvalue": 0.012023619663218781
# light_curve__sample_entropy: 0.011496839384201827
# light_curve__ratio_beyond_r_sigma__r_3: 0.011118143757221652
# light_curve__autocorrelation__lag_8: 0.010593175203960279
# light_curve__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean": 0.010030093500898781
# light_curve__ratio_beyond_r_sigma__r_1.5: 0.01002393603170106
# light_curve__fft_coefficient__attr_"real"__coeff_4: 0.009978580532702968
# light_curve__fft_coefficient__attr_"abs"__coeff_1: 0.009826259924457539
# light_curve__fourier_entropy__bins_10: 0.00833746585234755
# light_curve__fft_coefficient__attr_"abs"__coeff_51: 0.008256932375005991
# light_curve__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"mean": 0.008255834520508026
# light_curve__permutation_entropy__dimension_7__tau_1: 0.008047655642512593
# light_curve__autocorrelation__lag_9: 0.00796262758095528
# light_curve__index_mass_quantile__q_0.6: 0.007857081270477257
# light_curve__number_peaks__n_3: 0.007552891532547915
# light_curve__energy_ratio_by_chunks__num_segments_10__segment_focus_4: 0.007449415505250587
# light_curve__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0: 0.007207074315617324
# light_curve__ratio_beyond_r_sigma__r_2.5: 0.0067311313334732946
# light_curve__maximum: 0.006289195421541919
# light_curve__ar_coefficient__coeff_4__k_10: 0.006145477076043686
# light_curve__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"min": 0.005593946360398729
# light_curve__augmented_dickey_fuller__attr_"usedlag"__autolag_"AIC": 0.00555273628773216
# light_curve__count_above__t_0: 0.005549947634228979
# light_curve__energy_ratio_by_chunks__num_segments_10__segment_focus_7: 0.004937853906309251
# light_curve__friedrich_coefficients__coeff_0__m_3__r_30: 0.004895862406931471
# light_curve__permutation_entropy__dimension_6__tau_1: 0.00484708550663901
# light_curve__number_cwt_peaks__n_1: 0.004832409004120496
# light_curve__count_below__t_0: 0.004824999700948983
# light_curve__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"var": 0.004726523968150882
# light_curve__friedrich_coefficients__coeff_3__m_3__r_30: 0.004701550713335564
# light_curve__mean_n_absolute_max__number_of_maxima_7: 0.004633891888409554
# light_curve__partial_autocorrelation__lag_2: 0.004595548151582964
# light_curve__fft_coefficient__attr_"real"__coeff_9: 0.004570012197981463
# light_curve__fft_coefficient__attr_"real"__coeff_3: 0.0042631722240794355
# light_curve__permutation_entropy__dimension_5__tau_1: 0.004156397100518206
# light_curve__fft_coefficient__attr_"abs"__coeff_35: 0.004103898165981775
# light_curve__fft_aggregated__aggtype_"kurtosis": 0.004078865654002897

# %% [markdown]
# # **Try to get yours**
